# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %%
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
print('Training Set')
print(len(X_train))
print(X_train.shape)
print(y_train.shape)
# Out:
# Training Set
# 60000
# (60000, 28, 28)
# (60000,)

# %%
print('Testing Set')
print(len(X_test))
print(X_test.shape)
print(y_test.shape)
# Out:
# Testing Set
# 10000
# (10000, 28, 28)
# (10000,)

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i],cmap=plt.get_cmap('gray'))

# %%
X_train = 255 - X_train
X_test = 255 - X_test

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i],cmap=plt.get_cmap('gray'))

# %% [markdown]
# # Preprocessing

# %%
from keras.utils.np_utils import to_categorical

# %%
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

X_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

y_train.shape
# Out:
# (60000, 10)

# %%
X_all = np.concatenate((X_train, X_test))
y_all = np.concatenate((y_train,  y_test))

# %% [markdown]
# # Model Fitting

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, Flatten, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Convolutional Neural Network

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
filepath = "lens-digi-3.h5"
ckpt = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
rlp = ReduceLROnPlateau(patience=2)

def cnn(image_size):
    classifier = Sequential()
    classifier.add(Conv2D(32, (5, 5), input_shape = (*image_size, 1), activation = 'relu', padding='same'))
    classifier.add(Conv2D(32, (5, 5), activation = 'relu', padding='same'))
    classifier.add(MaxPooling2D(pool_size=(2, 2)))
    classifier.add(Dropout(0.25))
    classifier.add(Conv2D(64, (3, 3), activation = 'relu', padding='same'))
    classifier.add(Conv2D(64, (3, 3), activation = 'relu', padding='same'))
    classifier.add(MaxPooling2D(pool_size=(2, 2)))
    classifier.add(Dropout(0.25))
    classifier.add(Flatten())
    classifier.add(Dense(units = 10, activation = 'softmax'))
    classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    classifier.summary()
    return classifier


model = cnn((28,28))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        832
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 32)        25632
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                31370
# =================================================================
# Total params: 113,258
# Trainable params: 113,258
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='CNN3.png', show_shapes=True, show_layer_names=True)

# %%
datagen = ImageDataGenerator(
    rotation_range=10, 
    zoom_range = 0.1,
    width_shift_range=0.1, 
    height_shift_range=0.1,
    validation_split=0.1
)  

datagen.fit(X_all)

training_set = datagen.flow(
    x=X_all, y=y_all,
    subset='training'
)

validation_set = datagen.flow(
    x=X_all, y=y_all,
    subset='validation'
)

# %%
history = model.fit_generator(training_set, validation_data=validation_set, epochs=1000, callbacks=[es, ckpt, rlp])
# Out:
# Epoch 1/1000
# 1969/1969 [==============================] - 820s 416ms/step - loss: 0.2698 - accuracy: 0.9132 - val_loss: 0.0412 - val_accuracy: 0.9776
#
# Epoch 00001: val_loss improved from inf to 0.04116, saving model to lens-digi-3.h5
# Epoch 2/1000
# 1969/1969 [==============================] - 872s 443ms/step - loss: 0.0896 - accuracy: 0.9727 - val_loss: 0.1852 - val_accuracy: 0.9790
#
# Epoch 00002: val_loss did not improve from 0.04116
# Epoch 3/1000
# 1969/1969 [==============================] - 852s 433ms/step - loss: 0.0701 - accuracy: 0.9783 - val_loss: 0.0018 - val_accuracy: 0.9830
#
# Epoch 00003: val_loss improved from 0.04116 to 0.00184, saving model to lens-digi-3.h5
# Epoch 4/1000
# 1969/1969 [==============================] - 843s 428ms/step - loss: 0.0637 - accuracy: 0.9811 - val_loss: 0.0668 - val_accuracy: 0.9851
#
# Epoch 00004: val_loss did not improve from 0.00184
# Epoch 5/1000
# 1969/1969 [==============================] - 832s 423ms/step - loss: 0.0559 - accuracy: 0.9831 - val_loss: 0.0587 - val_accuracy: 0.9870
#
# Epoch 00005: val_loss did not improve from 0.00184
# Epoch 6/1000
# 1969/1969 [==============================] - 832s 423ms/step - loss: 0.0364 - accuracy: 0.9892 - val_loss: 0.0016 - val_accuracy: 0.9909
#
# Epoch 00006: val_loss improved from 0.00184 to 0.00164, saving model to lens-digi-3.h5
# Epoch 7/1000
# 1969/1969 [==============================] - 842s 428ms/step - loss: 0.0325 - accuracy: 0.9895 - val_loss: 0.0042 - val_accuracy: 0.9916
#
# Epoch 00007: val_loss did not improve from 0.00164
# Epoch 8/1000
# 1969/1969 [==============================] - 833s 423ms/step - loss: 0.0317 - accuracy: 0.9900 - val_loss: 0.0010 - val_accuracy: 0.9890
#
# Epoch 00008: val_loss improved from 0.00164 to 0.00101, saving model to lens-digi-3.h5
# Epoch 9/1000
# 1969/1969 [==============================] - 831s 422ms/step - loss: 0.0289 - accuracy: 0.9909 - val_loss: 0.0015 - val_accuracy: 0.9907
#
# Epoch 00009: val_loss did not improve from 0.00101
# Epoch 10/1000
# 1969/1969 [==============================] - 838s 426ms/step - loss: 0.0293 - accuracy: 0.9907 - val_loss: 0.0154 - val_accuracy: 0.9911
#
# Epoch 00010: val_loss did not improve from 0.00101
# Epoch 11/1000
# 1969/1969 [==============================] - 836s 425ms/step - loss: 0.0280 - accuracy: 0.9913 - val_loss: 2.6472e-04 - val_accuracy: 0.9911
#
# Epoch 00011: val_loss improved from 0.00101 to 0.00026, saving model to lens-digi-3.h5
# Epoch 12/1000
# 1969/1969 [==============================] - 844s 429ms/step - loss: 0.0275 - accuracy: 0.9916 - val_loss: 0.0775 - val_accuracy: 0.9923
#
# Epoch 00012: val_loss did not improve from 0.00026
# Epoch 13/1000
# 1969/1969 [==============================] - 829s 421ms/step - loss: 0.0276 - accuracy: 0.9917 - val_loss: 7.0689e-04 - val_accuracy: 0.9916
#
# Epoch 00013: val_loss did not improve from 0.00026
# Epoch 14/1000
# 1969/1969 [==============================] - 847s 430ms/step - loss: 0.0256 - accuracy: 0.9918 - val_loss: 0.1028 - val_accuracy: 0.9921
#
# Epoch 00014: val_loss did not improve from 0.00026
# Epoch 15/1000
# 1969/1969 [==============================] - 844s 429ms/step - loss: 0.0253 - accuracy: 0.9918 - val_loss: 0.0033 - val_accuracy: 0.9916
#
# Epoch 00015: val_loss did not improve from 0.00026
# Epoch 16/1000
# 1969/1969 [==============================] - 845s 429ms/step - loss: 0.0268 - accuracy: 0.9917 - val_loss: 0.0029 - val_accuracy: 0.9919
#
# Epoch 00016: val_loss did not improve from 0.00026
# Epoch 00016: early stopping

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 12))

fig.suptitle('Model Performance', fontsize=24) 

ax[0].plot(history.history['loss'], label='t-loss')
ax[0].plot(history.history['val_loss'], label='v-loss')
ax[0].set_title('Loss', fontsize=18)
ax[0].set_ylabel('Loss')

ax[1].plot(history.history['accuracy'], label='t-acc')
ax[1].plot(history.history['val_accuracy'], label='v-acc')
ax[1].set_title('Accuracy', fontsize=18)
ax[1].set_ylabel('Accuracy')


for i in range(2):
    ax[i].grid()
    ax[i].legend()
    ax[i].set_xlabel('Epochs')
    
plt.savefig('Training3.png')
