# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %%
train = pd.read_csv('../Data/emnist/emnist-balanced-train.csv', header=None)
test = pd.read_csv('../Data/emnist/emnist-balanced-test.csv', header=None)

# %%
X_train = train.iloc[:, 1:]
y_train = train.iloc[:, 0]
X_test = test.iloc[:, 1:]
y_test = test.iloc[:, 0]

del train, test

X_train = X_train[y_train >= 10].values
y_train = pd.get_dummies(y_train[y_train >= 10] - 10).values
X_test = X_test[y_test >= 10].values
y_test = pd.get_dummies(y_test[y_test >= 10] - 10).values

# %%
print('Training Set')
print(len(X_train))
print(X_train.shape)
print(y_train.shape)
# Out:
# Training Set
# 88800
# (88800, 784)
# (88800, 37)

# %%
print('Testing Set')
print(len(X_test))
print(X_test.shape)
print(y_test.shape)
# Out:
# Testing Set
# 14800
# (14800, 784)
# (14800, 37)

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %%
def rotate(image):
    image = image.reshape([28, 28])
    image = np.fliplr(image)
    image = np.rot90(image)
    return image.reshape([28 * 28])
X_train = np.apply_along_axis(rotate, 1, X_train)
X_test = np.apply_along_axis(rotate, 1, X_test)

# %%
X_train = 255 - X_train
X_test = 255 - X_test

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %% [markdown]
# # Preparation

# %%
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

X_train.shape
# Out:
# (88800, 28, 28, 1)

# %%
X_all = np.concatenate((X_train, X_test))
y_all = np.concatenate((y_train,  y_test))

del X_train, X_test, y_train, y_test

# %% [markdown]
# # Model Fitting

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, Flatten, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Convolutional Neural Network

# %%
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
filepath = "lens-alpha-1.h5"
ckpt = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
rlp = ReduceLROnPlateau(patience=2)

def cnn(image_size):
    classifier = Sequential()
    classifier.add(Conv2D(32, (3, 3), input_shape = (*image_size, 1), activation = 'relu'))
    classifier.add(MaxPooling2D(pool_size=(2, 2)))
    classifier.add(Flatten())
    classifier.add(Dense(units = 37, activation = 'softmax'))
    classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    classifier.summary()
    return classifier


model = cnn((28,28))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 37)                200133
# =================================================================
# Total params: 200,453
# Trainable params: 200,453
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='CNN1.png', show_shapes=True, show_layer_names=True)

# %%
history = model.fit(X_all, y_all, validation_split=0.1, epochs=1000, callbacks=[es, ckpt, rlp])
# Out:
# Train on 93240 samples, validate on 10360 samples
# Epoch 1/1000
# 93240/93240 [==============================] - 44s 470us/step - loss: 0.7432 - accuracy: 0.7925 - val_loss: 0.5163 - val_accuracy: 0.8504
#
# Epoch 00001: loss improved from inf to 0.74324, saving model to lens-alpha-1.h5
# Epoch 2/1000
# 93240/93240 [==============================] - 42s 453us/step - loss: 0.4396 - accuracy: 0.8683 - val_loss: 0.4724 - val_accuracy: 0.86126
#
# Epoch 00002: loss improved from 0.74324 to 0.43964, saving model to lens-alpha-1.h5
# Epoch 3/1000
# 93240/93240 [==============================] - 39s 416us/step - loss: 0.3825 - accuracy: 0.8832 - val_loss: 0.4396 - val_accuracy: 0.8743
#
# Epoch 00003: loss improved from 0.43964 to 0.38255, saving model to lens-alpha-1.h5
# Epoch 4/1000
# 93240/93240 [==============================] - 37s 400us/step - loss: 0.3452 - accuracy: 0.8924 - val_loss: 0.4479 - val_accuracy: 0.8653
#
# Epoch 00004: loss improved from 0.38255 to 0.34518, saving model to lens-alpha-1.h5
# Epoch 5/1000
# 93240/93240 [==============================] - 37s 395us/step - loss: 0.3182 - accuracy: 0.9005 - val_loss: 0.4201 - val_accuracy: 0.8797
#
# Epoch 00005: loss improved from 0.34518 to 0.31819, saving model to lens-alpha-1.h5
# Epoch 6/1000
# 93240/93240 [==============================] - 38s 404us/step - loss: 0.2947 - accuracy: 0.9070 - val_loss: 0.4132 - val_accuracy: 0.8785
#
# Epoch 00006: loss improved from 0.31819 to 0.29466, saving model to lens-alpha-1.h5
# Epoch 7/1000
# 93240/93240 [==============================] - 38s 402us/step - loss: 0.2744 - accuracy: 0.9113 - val_loss: 0.4275 - val_accuracy: 0.8771
#
# Epoch 00007: loss improved from 0.29466 to 0.27437, saving model to lens-alpha-1.h5
# Epoch 8/1000
# 93240/93240 [==============================] - 38s 409us/step - loss: 0.2550 - accuracy: 0.9178 - val_loss: 0.4296 - val_accuracy: 0.8758
#
# Epoch 00008: loss improved from 0.27437 to 0.25500, saving model to lens-alpha-1.h5
# Epoch 9/1000
# 93240/93240 [==============================] - 37s 394us/step - loss: 0.1999 - accuracy: 0.9369 - val_loss: 0.4021 - val_accuracy: 0.8868
#
# Epoch 00009: loss improved from 0.25500 to 0.19987, saving model to lens-alpha-1.h5
# Epoch 10/1000
# 93240/93240 [==============================] - 37s 395us/step - loss: 0.1910 - accuracy: 0.9410 - val_loss: 0.4010 - val_accuracy: 0.8868
#
# Epoch 00010: loss improved from 0.19987 to 0.19101, saving model to lens-alpha-1.h5
# Epoch 11/1000
# 93240/93240 [==============================] - 37s 400us/step - loss: 0.1872 - accuracy: 0.9425 - val_loss: 0.4030 - val_accuracy: 0.8864
#
# Epoch 00011: loss improved from 0.19101 to 0.18716, saving model to lens-alpha-1.h5
# Epoch 12/1000
# 93240/93240 [==============================] - 37s 397us/step - loss: 0.1843 - accuracy: 0.9431 - val_loss: 0.4044 - val_accuracy: 0.8861
#
# Epoch 00012: loss improved from 0.18716 to 0.18428, saving model to lens-alpha-1.h5
# Epoch 13/1000
# 93240/93240 [==============================] - 37s 396us/step - loss: 0.1769 - accuracy: 0.9459 - val_loss: 0.4030 - val_accuracy: 0.8861
#
# Epoch 00013: loss improved from 0.18428 to 0.17689, saving model to lens-alpha-1.h5
# Epoch 14/1000
# 93240/93240 [==============================] - 39s 417us/step - loss: 0.1762 - accuracy: 0.9464 - val_loss: 0.4030 - val_accuracy: 0.8860
#
# Epoch 00014: loss improved from 0.17689 to 0.17624, saving model to lens-alpha-1.h5
# Epoch 15/1000
# 93240/93240 [==============================] - 37s 399us/step - loss: 0.1754 - accuracy: 0.9465 - val_loss: 0.4030 - val_accuracy: 0.8857
#
# Epoch 00015: loss improved from 0.17624 to 0.17536, saving model to lens-alpha-1.h5
# Epoch 16/1000
# 93240/93240 [==============================] - 37s 396us/step - loss: 0.1753 - accuracy: 0.9467 - val_loss: 0.4030 - val_accuracy: 0.8855
#
# Epoch 00016: loss improved from 0.17536 to 0.17531, saving model to lens-alpha-1.h5
# Epoch 17/1000
# 93240/93240 [==============================] - 37s 394us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8855
#
# Epoch 00017: loss improved from 0.17531 to 0.17520, saving model to lens-alpha-1.h5
# Epoch 18/1000
# 93240/93240 [==============================] - 40s 430us/step - loss: 0.1752 - accuracy: 0.9467 - val_loss: 0.4030 - val_accuracy: 0.8855
#
# Epoch 00018: loss improved from 0.17520 to 0.17520, saving model to lens-alpha-1.h5
# Epoch 19/1000
# 93240/93240 [==============================] - 38s 410us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8855
#
# Epoch 00019: loss improved from 0.17520 to 0.17519, saving model to lens-alpha-1.h5
# Epoch 20/1000
# 93240/93240 [==============================] - 37s 396us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00020: loss improved from 0.17519 to 0.17519, saving model to lens-alpha-1.h5
# Epoch 21/1000
# 93240/93240 [==============================] - 37s 397us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00021: loss improved from 0.17519 to 0.17519, saving model to lens-alpha-1.h5
# Epoch 22/1000
# 93240/93240 [==============================] - 37s 395us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00022: loss improved from 0.17519 to 0.17519, saving model to lens-alpha-1.h5
# Epoch 23/1000
# 93240/93240 [==============================] - 37s 397us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00023: loss improved from 0.17519 to 0.17519, saving model to lens-alpha-1.h5
# Epoch 24/1000
# 93240/93240 [==============================] - 37s 395us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00024: loss improved from 0.17519 to 0.17519, saving model to lens-alpha-1.h5
# Epoch 25/1000
# 93240/93240 [==============================] - 37s 395us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00025: loss did not improve from 0.17519
# Epoch 26/1000
# 93240/93240 [==============================] - 38s 404us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00026: loss did not improve from 0.17519
# Epoch 27/1000
# 93240/93240 [==============================] - 37s 397us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00027: loss did not improve from 0.17519
# Epoch 28/1000
# 93240/93240 [==============================] - 37s 396us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00028: loss did not improve from 0.17519
# Epoch 29/1000
# 93240/93240 [==============================] - 37s 395us/step - loss: 0.1752 - accuracy: 0.9468 - val_loss: 0.4030 - val_accuracy: 0.8856
#
# Epoch 00029: loss did not improve from 0.17519
# Epoch 00029: early stopping

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 12))

fig.suptitle('Model Performance', fontsize=24) 

ax[0].plot(history.history['loss'], label='t-loss')
ax[0].plot(history.history['val_loss'], label='v-loss')
ax[0].set_title('Loss', fontsize=18)
ax[0].set_ylabel('Loss')

ax[1].plot(history.history['accuracy'], label='t-acc')
ax[1].plot(history.history['val_accuracy'], label='v-acc')
ax[1].set_title('Accuracy', fontsize=18)
ax[1].set_ylabel('Accuracy')


for i in range(2):
    ax[i].grid()
    ax[i].legend()
    ax[i].set_xlabel('Epochs')
    
plt.savefig('Training1.png')
