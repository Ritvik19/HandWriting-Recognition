# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %%
train = pd.read_csv('../Data/emnist/emnist-balanced-train.csv', header=None)
test = pd.read_csv('../Data/emnist/emnist-balanced-test.csv', header=None)

# %%
X_train = train.iloc[:, 1:]
y_train = train.iloc[:, 0]
X_test = test.iloc[:, 1:]
y_test = test.iloc[:, 0]

del train, test

X_train = X_train[y_train >= 10].values
y_train = pd.get_dummies(y_train[y_train >= 10] - 10).values
X_test = X_test[y_test >= 10].values
y_test = pd.get_dummies(y_test[y_test >= 10] - 10).values

# %%
print('Training Set')
print(len(X_train))
print(X_train.shape)
print(y_train.shape)
# Out:
# Training Set
# 88800
# (88800, 784)
# (88800, 37)

# %%
print('Testing Set')
print(len(X_test))
print(X_test.shape)
print(y_test.shape)
# Out:
# Testing Set
# 14800
# (14800, 784)
# (14800, 37)

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %%
def rotate(image):
    image = image.reshape([28, 28])
    image = np.fliplr(image)
    image = np.rot90(image)
    return image.reshape([28 * 28])
X_train = np.apply_along_axis(rotate, 1, X_train)
X_test = np.apply_along_axis(rotate, 1, X_test)

# %%
X_train = 255 - X_train
X_test = 255 - X_test

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %% [markdown]
# # Preprocessing

# %%
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

X_train.shape
# Out:
# (88800, 28, 28, 1)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0

# %%
X_all = np.concatenate((X_train, X_test))
y_all = np.concatenate((y_train,  y_test))

del X_train, X_test, y_train, y_test

# %% [markdown]
# # Model Fitting

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, Flatten, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Convolutional Neural Network

# %%
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
filepath = "lens-alpha.h5"
ckpt = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
rlp = ReduceLROnPlateau(patience=2)

def cnn(image_size):
    classifier = Sequential()
    classifier.add(Conv2D(32, (3, 3), input_shape = (*image_size, 1), activation = 'relu'))
    classifier.add(MaxPooling2D(pool_size=(2, 2)))
    classifier.add(Flatten())
    classifier.add(Dense(units = 37, activation = 'softmax'))
    classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    classifier.summary()
    return classifier


model = cnn((28,28))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 37)                200133
# =================================================================
# Total params: 200,453
# Trainable params: 200,453
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='CNN.png', show_shapes=True, show_layer_names=True)

# %%
history = model.fit(X_all, y_all, validation_split=0.1, epochs=1000, callbacks=[es, ckpt, rlp])
# Out:
# Train on 93240 samples, validate on 10360 samples
# Epoch 1/1000
# 93240/93240 [==============================] - 40s 428us/step - loss: 0.7663 - accuracy: 0.7846 - val_loss: 0.5379 - val_accuracy: 0.8411
#
# Epoch 00001: loss improved from inf to 0.76625, saving model to lens-alpha.h5
# Epoch 2/1000
# 93240/93240 [==============================] - 40s 431us/step - loss: 0.4370 - accuracy: 0.8689 - val_loss: 0.4671 - val_accuracy: 0.8616
#
# Epoch 00002: loss improved from 0.76625 to 0.43696, saving model to lens-alpha.h5
# Epoch 3/1000
# 93240/93240 [==============================] - 40s 431us/step - loss: 0.3776 - accuracy: 0.8847 - val_loss: 0.4406 - val_accuracy: 0.8707
#
# Epoch 00003: loss improved from 0.43696 to 0.37760, saving model to lens-alpha.h5
# Epoch 4/1000
# 93240/93240 [==============================] - 40s 424us/step - loss: 0.3399 - accuracy: 0.8936 - val_loss: 0.4415 - val_accuracy: 0.8722
#
# Epoch 00004: loss improved from 0.37760 to 0.33989, saving model to lens-alpha.h5
# Epoch 5/1000
# 93240/93240 [==============================] - 40s 426us/step - loss: 0.3094 - accuracy: 0.9031 - val_loss: 0.4184 - val_accuracy: 0.8759
#
# Epoch 00005: loss improved from 0.33989 to 0.30944, saving model to lens-alpha.h5
# Epoch 6/1000
# 93240/93240 [==============================] - 44s 467us/step - loss: 0.2836 - accuracy: 0.9097 - val_loss: 0.4141 - val_accuracy: 0.8819
#
# Epoch 00006: loss improved from 0.30944 to 0.28356, saving model to lens-alpha.h5
# Epoch 7/1000
# 93240/93240 [==============================] - 43s 462us/step - loss: 0.2617 - accuracy: 0.9153 - val_loss: 0.4244 - val_accuracy: 0.8817
#
# Epoch 00007: loss improved from 0.28356 to 0.26175, saving model to lens-alpha.h5
# Epoch 8/1000
# 93240/93240 [==============================] - 39s 420us/step - loss: 0.2431 - accuracy: 0.9211 - val_loss: 0.4174 - val_accuracy: 0.8847
#
# Epoch 00008: loss improved from 0.26175 to 0.24309, saving model to lens-alpha.h5
# Epoch 9/1000
# 93240/93240 [==============================] - 43s 457us/step - loss: 0.1868 - accuracy: 0.9418 - val_loss: 0.4012 - val_accuracy: 0.8872
#
# Epoch 00009: loss improved from 0.24309 to 0.18682, saving model to lens-alpha.h5
# Epoch 10/1000
# 93240/93240 [==============================] - 39s 415us/step - loss: 0.1784 - accuracy: 0.9444 - val_loss: 0.4000 - val_accuracy: 0.8873
#
# Epoch 00010: loss improved from 0.18682 to 0.17838, saving model to lens-alpha.h5
# Epoch 11/1000
# 93240/93240 [==============================] - 37s 397us/step - loss: 0.1744 - accuracy: 0.9457 - val_loss: 0.4019 - val_accuracy: 0.8867
#
# Epoch 00011: loss improved from 0.17838 to 0.17436, saving model to lens-alpha.h5
# Epoch 12/1000
# 93240/93240 [==============================] - 37s 399us/step - loss: 0.1713 - accuracy: 0.9467 - val_loss: 0.4032 - val_accuracy: 0.8873
#
# Epoch 00012: loss improved from 0.17436 to 0.17125, saving model to lens-alpha.h5
# Epoch 13/1000
# 93240/93240 [==============================] - 39s 416us/step - loss: 0.1642 - accuracy: 0.9493 - val_loss: 0.4022 - val_accuracy: 0.8877
#
# Epoch 00013: loss improved from 0.17125 to 0.16423, saving model to lens-alpha.h5
# Epoch 14/1000
# 93240/93240 [==============================] - 41s 436us/step - loss: 0.1636 - accuracy: 0.9500 - val_loss: 0.4024 - val_accuracy: 0.8870
#
# Epoch 00014: loss improved from 0.16423 to 0.16356, saving model to lens-alpha.h5
# Epoch 15/1000
# 93240/93240 [==============================] - 36s 391us/step - loss: 0.1626 - accuracy: 0.9501 - val_loss: 0.4024 - val_accuracy: 0.8875
#
# Epoch 00015: loss improved from 0.16356 to 0.16265, saving model to lens-alpha.h5
# Epoch 16/1000
# 93240/93240 [==============================] - 40s 433us/step - loss: 0.1626 - accuracy: 0.9501 - val_loss: 0.4024 - val_accuracy: 0.8877
#
# Epoch 00016: loss improved from 0.16265 to 0.16260, saving model to lens-alpha.h5
# Epoch 17/1000
# 93240/93240 [==============================] - 41s 444us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4024 - val_accuracy: 0.8877
#
# Epoch 00017: loss improved from 0.16260 to 0.16250, saving model to lens-alpha.h5
# Epoch 18/1000
# 93240/93240 [==============================] - 41s 435us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00018: loss improved from 0.16250 to 0.16250, saving model to lens-alpha.h5
# Epoch 19/1000
# 93240/93240 [==============================] - 39s 416us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00019: loss improved from 0.16250 to 0.16249, saving model to lens-alpha.h5
# Epoch 20/1000
# 93240/93240 [==============================] - 39s 423us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00020: loss improved from 0.16249 to 0.16249, saving model to lens-alpha.h5
# Epoch 21/1000
# 93240/93240 [==============================] - 40s 429us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00021: loss improved from 0.16249 to 0.16249, saving model to lens-alpha.h5
# Epoch 22/1000
# 93240/93240 [==============================] - 39s 422us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00022: loss improved from 0.16249 to 0.16249, saving model to lens-alpha.h5
# Epoch 23/1000
# 93240/93240 [==============================] - 38s 411us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00023: loss improved from 0.16249 to 0.16249, saving model to lens-alpha.h5
# Epoch 24/1000
# 93240/93240 [==============================] - 41s 436us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00024: loss did not improve from 0.16249
# Epoch 25/1000
# 93240/93240 [==============================] - 42s 449us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00025: loss did not improve from 0.16249
# Epoch 26/1000
# 93240/93240 [==============================] - 39s 421us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00026: loss did not improve from 0.16249
# Epoch 27/1000
# 93240/93240 [==============================] - 38s 408us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00027: loss did not improve from 0.16249
# Epoch 28/1000
# 93240/93240 [==============================] - 38s 407us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00028: loss improved from 0.16249 to 0.16249, saving model to lens-alpha.h5
# Epoch 29/1000
# 93240/93240 [==============================] - 43s 466us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00029: loss improved from 0.16249 to 0.16249, saving model to lens-alpha.h5
# Epoch 30/1000
# 93240/93240 [==============================] - 38s 405us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00030: loss did not improve from 0.16249
# Epoch 31/1000
# 93240/93240 [==============================] - 39s 421us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00031: loss did not improve from 0.16249
# Epoch 32/1000
# 93240/93240 [==============================] - 41s 442us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00032: loss did not improve from 0.16249
# Epoch 33/1000
# 93240/93240 [==============================] - 40s 425us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00033: loss did not improve from 0.16249
# Epoch 34/1000
# 93240/93240 [==============================] - 40s 432us/step - loss: 0.1625 - accuracy: 0.9502 - val_loss: 0.4025 - val_accuracy: 0.8877
#
# Epoch 00034: loss did not improve from 0.16249
# Epoch 00034: early stopping

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 12))

fig.suptitle('Model Performance', fontsize=24) 

ax[0].plot(history.history['loss'], label='t-loss')
ax[0].plot(history.history['val_loss'], label='v-loss')
ax[0].set_title('Loss', fontsize=18)
ax[0].set_ylabel('Loss')

ax[1].plot(history.history['accuracy'], label='t-acc')
ax[1].plot(history.history['val_accuracy'], label='v-acc')
ax[1].set_title('Accuracy', fontsize=18)
ax[1].set_ylabel('Accuracy')


for i in range(2):
    ax[i].grid()
    ax[i].legend()
    ax[i].set_xlabel('Epochs')
    
plt.savefig('Training.png')
