# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %%
train = pd.read_csv('../Data/emnist/emnist-balanced-train.csv', header=None)
test = pd.read_csv('../Data/emnist/emnist-balanced-test.csv', header=None)

# %%
X_train = train.iloc[:, 1:].values
y_train = pd.get_dummies(train.iloc[:, 0]).values
X_test = test.iloc[:, 1:].values
y_test = pd.get_dummies(test.iloc[:, 0]).values

del train, test

# %%
print('Training Set')
print(len(X_train))
print(X_train.shape)
print(y_train.shape)
# Out:
# Training Set
# 112800
# (112800, 784)
# (112800, 47)

# %%
print('Testing Set')
print(len(X_test))
print(X_test.shape)
print(y_test.shape)
# Out:
# Testing Set
# 18800
# (18800, 784)
# (18800, 47)

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %%
def rotate(image):
    image = image.reshape([28, 28])
    image = np.fliplr(image)
    image = np.rot90(image)
    return image.reshape([28 * 28])
X_train = np.apply_along_axis(rotate, 1, X_train)
X_test = np.apply_along_axis(rotate, 1, X_test)

# %%
X_train = 255 - X_train
X_test = 255 - X_test

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %% [markdown]
# # Preprocessing

# %%
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

X_train.shape
# Out:
# (112800, 28, 28, 1)

# %%
X_all = np.concatenate((X_train, X_test))
y_all = np.concatenate((y_train,  y_test))

del X_train, X_test, y_train, y_test

# %% [markdown]
# # Model Fitting

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, Flatten, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Convolutional Neural Network

# %%
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
filepath = "lens-alnum-1.h5"
ckpt = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
rlp = ReduceLROnPlateau(patience=2)

def cnn(image_size):
    classifier = Sequential()
    classifier.add(Conv2D(32, (3, 3), input_shape = (*image_size, 1), activation = 'relu'))
    classifier.add(MaxPooling2D(pool_size=(2, 2)))
    classifier.add(Flatten())
    classifier.add(Dense(units = 47, activation = 'softmax'))
    classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    classifier.summary()
    return classifier


model = cnn((28,28))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 47)                254223
# =================================================================
# Total params: 254,543
# Trainable params: 254,543
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='CNN1.png', show_shapes=True, show_layer_names=True)

# %%
history = model.fit(X_all, y_all, validation_split=0.1, epochs=1000, callbacks=[es, ckpt, rlp])
# Out:
# Train on 118440 samples, validate on 13160 samples
# Epoch 1/1000
# 118440/118440 [==============================] - 62s 521us/step - loss: 0.8471 - accuracy: 0.7525 - val_loss: 0.6228 - val_accuracy: 0.8125
#
# Epoch 00001: loss improved from inf to 0.84709, saving model to lens-alnum-1.h5
# Epoch 2/1000
# 118440/118440 [==============================] - 79s 664us/step - loss: 0.5275 - accuracy: 0.8317 - val_loss: 0.5462 - val_accuracy: 0.8285
#
# Epoch 00002: loss improved from 0.84709 to 0.52745, saving model to lens-alnum-1.h5
# Epoch 3/1000
# 118440/118440 [==============================] - 102s 862us/step - loss: 0.4633 - accuracy: 0.8494 - val_loss: 0.5244 - val_accuracy: 0.8378
#
# Epoch 00003: loss improved from 0.52745 to 0.46331, saving model to lens-alnum-1.h5
# Epoch 4/1000
# 118440/118440 [==============================] - 99s 834us/step - loss: 0.4194 - accuracy: 0.8620 - val_loss: 0.5132 - val_accuracy: 0.8374
#
# Epoch 00004: loss improved from 0.46331 to 0.41944, saving model to lens-alnum-1.h5
# Epoch 5/1000
# 118440/118440 [==============================] - 92s 773us/step - loss: 0.3557 - accuracy: 0.8804 - val_loss: 0.4948 - val_accuracy: 0.8481
#
# Epoch 00006: loss improved from 0.38470 to 0.35574, saving model to lens-alnum-1.h5
# Epoch 7/1000
# 118440/118440 [==============================] - 97s 821us/step - loss: 0.3315 - accuracy: 0.8864 - val_loss: 0.5067 - val_accuracy: 0.8438
#
# Epoch 00007: loss improved from 0.35574 to 0.33149, saving model to lens-alnum-1.h5
# Epoch 8/1000
# 118440/118440 [==============================] - 102s 862us/step - loss: 0.3111 - accuracy: 0.8925 - val_loss: 0.5056 - val_accuracy: 0.8448
#
# Epoch 00008: loss improved from 0.33149 to 0.31110, saving model to lens-alnum-1.h5
# Epoch 9/1000
# 118440/118440 [==============================] - 101s 852us/step - loss: 0.2458 - accuracy: 0.9167 - val_loss: 0.4817 - val_accuracy: 0.8525
#
# Epoch 00009: loss improved from 0.31110 to 0.24583, saving model to lens-alnum-1.h5
# Epoch 10/1000
# 118440/118440 [==============================] - 98s 829us/step - loss: 0.2363 - accuracy: 0.9205 - val_loss: 0.4815 - val_accuracy: 0.8552
#
# Epoch 00010: loss improved from 0.24583 to 0.23628, saving model to lens-alnum-1.h5
# Epoch 11/1000
# 118440/118440 [==============================] - 98s 826us/step - loss: 0.2319 - accuracy: 0.9224 - val_loss: 0.4841 - val_accuracy: 0.8558
#
# Epoch 00011: loss improved from 0.23628 to 0.23190, saving model to lens-alnum-1.h5
# Epoch 12/1000
# 118440/118440 [==============================] - 99s 834us/step - loss: 0.2285 - accuracy: 0.9235 - val_loss: 0.4859 - val_accuracy: 0.8545
#
# Epoch 00012: loss improved from 0.23190 to 0.22845, saving model to lens-alnum-1.h5
# Epoch 13/1000
# 118440/118440 [==============================] - 97s 820us/step - loss: 0.2204 - accuracy: 0.9269 - val_loss: 0.4843 - val_accuracy: 0.8549
#
# Epoch 00013: loss improved from 0.22845 to 0.22044, saving model to lens-alnum-1.h5
# Epoch 14/1000
# 118440/118440 [==============================] - 100s 847us/step - loss: 0.2196 - accuracy: 0.9272 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00014: loss improved from 0.22044 to 0.21961, saving model to lens-alnum-1.h5
# Epoch 15/1000
# 118440/118440 [==============================] - 100s 847us/step - loss: 0.2186 - accuracy: 0.9275 - val_loss: 0.4849 - val_accuracy: 0.8545
#
# Epoch 00015: loss improved from 0.21961 to 0.21859, saving model to lens-alnum-1.h5
# Epoch 16/1000
# 118440/118440 [==============================] - 98s 830us/step - loss: 0.2185 - accuracy: 0.9275 - val_loss: 0.4849 - val_accuracy: 0.8542
#
# Epoch 00016: loss improved from 0.21859 to 0.21853, saving model to lens-alnum-1.h5
# Epoch 17/1000
# 118440/118440 [==============================] - 103s 870us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543184 -
#
# Epoch 00017: loss improved from 0.21853 to 0.21840, saving model to lens-alnum-1.h5
# Epoch 18/1000
# 118440/118440 [==============================] - 100s 842us/step - loss: 0.2184 - accuracy: 0.9278 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00018: loss improved from 0.21840 to 0.21840, saving model to lens-alnum-1.h5
# Epoch 19/1000
# 118440/118440 [==============================] - 106s 896us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00019: loss improved from 0.21840 to 0.21839, saving model to lens-alnum-1.h5
# Epoch 20/1000
# 118440/118440 [==============================] - 103s 870us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00020: loss improved from 0.21839 to 0.21839, saving model to lens-alnum-1.h5
# Epoch 21/1000
# 118440/118440 [==============================] - 101s 855us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00021: loss improved from 0.21839 to 0.21839, saving model to lens-alnum-1.h5
# Epoch 22/1000
# 118440/118440 [==============================] - 100s 842us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00022: loss improved from 0.21839 to 0.21839, saving model to lens-alnum-1.h5
# Epoch 23/1000
# 118440/118440 [==============================] - 101s 849us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00023: loss improved from 0.21839 to 0.21839, saving model to lens-alnum-1.h5
# Epoch 24/1000
# 118440/118440 [==============================] - 109s 918us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00024: loss improved from 0.21839 to 0.21839, saving model to lens-alnum-1.h5
# Epoch 25/1000
# 118440/118440 [==============================] - 105s 890us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00025: loss improved from 0.21839 to 0.21839, saving model to lens-alnum-1.h5
# Epoch 26/1000
# 118440/118440 [==============================] - 106s 892us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00026: loss improved from 0.21839 to 0.21839, saving model to lens-alnum-1.h5
# Epoch 27/1000
# 118440/118440 [==============================] - 103s 873us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00027: loss did not improve from 0.21839
# Epoch 28/1000
# 118440/118440 [==============================] - 107s 904us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00028: loss did not improve from 0.21839
# Epoch 29/1000
# 118440/118440 [==============================] - 103s 874us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00029: loss did not improve from 0.21839
# Epoch 30/1000
# 118440/118440 [==============================] - 103s 869us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00030: loss did not improve from 0.21839
# Epoch 31/1000
# 118440/118440 [==============================] - 105s 887us/step - loss: 0.2184 - accuracy: 0.9277 - val_loss: 0.4849 - val_accuracy: 0.8543
#
# Epoch 00031: loss did not improve from 0.21839
# Epoch 00031: early stopping

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 12))

fig.suptitle('Model Performance', fontsize=24) 

ax[0].plot(history.history['loss'], label='t-loss')
ax[0].plot(history.history['val_loss'], label='v-loss')
ax[0].set_title('Loss', fontsize=18)
ax[0].set_ylabel('Loss')

ax[1].plot(history.history['accuracy'], label='t-acc')
ax[1].plot(history.history['val_accuracy'], label='v-acc')
ax[1].set_title('Accuracy', fontsize=18)
ax[1].set_ylabel('Accuracy')


for i in range(2):
    ax[i].grid()
    ax[i].legend()
    ax[i].set_xlabel('Epochs')
    
plt.savefig('Training1.png')
