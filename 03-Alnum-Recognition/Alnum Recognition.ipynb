# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %%
train = pd.read_csv('../Data/emnist/emnist-balanced-train.csv', header=None)
test = pd.read_csv('../Data/emnist/emnist-balanced-test.csv', header=None)

# %%
X_train = train.iloc[:, 1:].values
y_train = pd.get_dummies(train.iloc[:, 0]).values
X_test = test.iloc[:, 1:].values
y_test = pd.get_dummies(test.iloc[:, 0]).values

del train, test

# %%
print('Training Set')
print(len(X_train))
print(X_train.shape)
print(y_train.shape)
# Out:
# Training Set
# 112800
# (112800, 784)
# (112800, 47)

# %%
print('Testing Set')
print(len(X_test))
print(X_test.shape)
print(y_test.shape)
# Out:
# Testing Set
# 18800
# (18800, 784)
# (18800, 47)

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %%
def rotate(image):
    image = image.reshape([28, 28])
    image = np.fliplr(image)
    image = np.rot90(image)
    return image.reshape([28 * 28])
X_train = np.apply_along_axis(rotate, 1, X_train)
X_test = np.apply_along_axis(rotate, 1, X_test)

# %%
X_train = 255 - X_train
X_test = 255 - X_test

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_train[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %% [markdown]
# # Preprocessing

# %%
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

X_train.shape
# Out:
# (112800, 28, 28, 1)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0

# %%
X_all = np.concatenate((X_train, X_test))
y_all = np.concatenate((y_train,  y_test))

del X_train, X_test, y_train, y_test

# %% [markdown]
# # Model Fitting

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, Flatten, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Convolutional Neural Network

# %%
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=5)
filepath = "lens-alnum.h5"
ckpt = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
rlp = ReduceLROnPlateau(patience=2)

def cnn(image_size):
    classifier = Sequential()
    classifier.add(Conv2D(32, (3, 3), input_shape = (*image_size, 1), activation = 'relu'))
    classifier.add(MaxPooling2D(pool_size=(2, 2)))
    classifier.add(Flatten())
    classifier.add(Dense(units = 47, activation = 'softmax'))
    classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    classifier.summary()
    return classifier


model = cnn((28,28))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 47)                254223
# =================================================================
# Total params: 254,543
# Trainable params: 254,543
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='CNN.png', show_shapes=True, show_layer_names=True)

# %%
history = model.fit(X_all, y_all, validation_split=0.1, epochs=1000, callbacks=[es, ckpt, rlp])
# Out:
# Train on 118440 samples, validate on 13160 samples
# Epoch 1/1000
# 118440/118440 [==============================] - 56s 473us/step - loss: 0.8476 - accuracy: 0.7509 - val_loss: 0.6041 - val_accuracy: 0.8149
#
# Epoch 00001: loss improved from inf to 0.84761, saving model to lens-alnum.h5
# Epoch 2/1000
# 118440/118440 [==============================] - 58s 486us/step - loss: 0.5265 - accuracy: 0.8322 - val_loss: 0.5441 - val_accuracy: 0.8264
#
# Epoch 00002: loss improved from 0.84761 to 0.52646, saving model to lens-alnum.h5
# Epoch 3/1000
# 118440/118440 [==============================] - 55s 461us/step - loss: 0.4615 - accuracy: 0.8502 - val_loss: 0.5262 - val_accuracy: 0.8351
#
# Epoch 00003: loss improved from 0.52646 to 0.46150, saving model to lens-alnum.h5
# Epoch 4/1000
# 118440/118440 [==============================] - 55s 461us/step - loss: 0.4192 - accuracy: 0.8622 - val_loss: 0.5128 - val_accuracy: 0.8368
#
# Epoch 00004: loss improved from 0.46150 to 0.41918, saving model to lens-alnum.h5
# Epoch 5/1000
# 118440/118440 [==============================] - 52s 442us/step - loss: 0.3847 - accuracy: 0.8713 - val_loss: 0.5084 - val_accuracy: 0.8408
#
# Epoch 00005: loss improved from 0.41918 to 0.38469, saving model to lens-alnum.h5
# Epoch 6/1000
# 118440/118440 [==============================] - 52s 439us/step - loss: 0.3572 - accuracy: 0.8790 - val_loss: 0.5055 - val_accuracy: 0.8432
#
# Epoch 00006: loss improved from 0.38469 to 0.35721, saving model to lens-alnum.h5
# Epoch 7/1000
# 118440/118440 [==============================] - 71s 601us/step - loss: 0.3331 - accuracy: 0.8864 - val_loss: 0.5127 - val_accuracy: 0.8389
#
# Epoch 00007: loss improved from 0.35721 to 0.33311, saving model to lens-alnum.h5
# Epoch 8/1000
# 118440/118440 [==============================] - 58s 490us/step - loss: 0.3138 - accuracy: 0.8918 - val_loss: 0.5056 - val_accuracy: 0.8422
#
# Epoch 00008: loss improved from 0.33311 to 0.31377, saving model to lens-alnum.h5
# Epoch 9/1000
# 118440/118440 [==============================] - 59s 501us/step - loss: 0.2477 - accuracy: 0.9160 - val_loss: 0.4850 - val_accuracy: 0.8544
#
# Epoch 00009: loss improved from 0.31377 to 0.24770, saving model to lens-alnum.h5
# Epoch 10/1000
# 118440/118440 [==============================] - 84s 708us/step - loss: 0.2380 - accuracy: 0.9198 - val_loss: 0.4842 - val_accuracy: 0.8534
#
# Epoch 00010: loss improved from 0.24770 to 0.23802, saving model to lens-alnum.h5
# Epoch 11/1000
# 118440/118440 [==============================] - 77s 651us/step - loss: 0.2338 - accuracy: 0.9214 - val_loss: 0.4875 - val_accuracy: 0.8533
#
# Epoch 00011: loss improved from 0.23802 to 0.23378, saving model to lens-alnum.h5
# Epoch 12/1000
# 118440/118440 [==============================] - 63s 530us/step - loss: 0.2303 - accuracy: 0.9224 - val_loss: 0.4890 - val_accuracy: 0.8515
#
# Epoch 00012: loss improved from 0.23378 to 0.23028, saving model to lens-alnum.h5
# Epoch 13/1000
# 118440/118440 [==============================] - 57s 477us/step - loss: 0.2221 - accuracy: 0.9258 - val_loss: 0.4868 - val_accuracy: 0.8537
#
# Epoch 00013: loss improved from 0.23028 to 0.22209, saving model to lens-alnum.h5
# Epoch 14/1000
# 118440/118440 [==============================] - 57s 483us/step - loss: 0.2214 - accuracy: 0.9262 - val_loss: 0.4870 - val_accuracy: 0.8542
#
# Epoch 00014: loss improved from 0.22209 to 0.22137, saving model to lens-alnum.h5
# Epoch 15/1000
# 118440/118440 [==============================] - 55s 460us/step - loss: 0.2203 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8541
#
# Epoch 00015: loss improved from 0.22137 to 0.22032, saving model to lens-alnum.h5
# Epoch 16/1000
# 118440/118440 [==============================] - 58s 493us/step - loss: 0.2203 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00016: loss improved from 0.22032 to 0.22025, saving model to lens-alnum.h5
# Epoch 17/1000
# 118440/118440 [==============================] - 57s 483us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00017: loss improved from 0.22025 to 0.22013, saving model to lens-alnum.h5
# Epoch 18/1000
# 118440/118440 [==============================] - 55s 465us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00018: loss improved from 0.22013 to 0.22013, saving model to lens-alnum.h5
# Epoch 19/1000
# 118440/118440 [==============================] - 57s 479us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00019: loss improved from 0.22013 to 0.22012, saving model to lens-alnum.h5
# Epoch 20/1000
# 118440/118440 [==============================] - 54s 457us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00020: loss improved from 0.22012 to 0.22012, saving model to lens-alnum.h5
# Epoch 21/1000
# 118440/118440 [==============================] - 56s 475us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00021: loss improved from 0.22012 to 0.22012, saving model to lens-alnum.h5
# Epoch 22/1000
# 118440/118440 [==============================] - 55s 466us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00022: loss improved from 0.22012 to 0.22012, saving model to lens-alnum.h5
# Epoch 23/1000
# 118440/118440 [==============================] - 54s 456us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00023: loss improved from 0.22012 to 0.22012, saving model to lens-alnum.h5
# Epoch 24/1000
# 118440/118440 [==============================] - 54s 459us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00024: loss improved from 0.22012 to 0.22012, saving model to lens-alnum.h5
# Epoch 25/1000
# 118440/118440 [==============================] - 54s 454us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00025: loss improved from 0.22012 to 0.22012, saving model to lens-alnum.h5
# Epoch 26/1000
# 118440/118440 [==============================] - 54s 455us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00026: loss did not improve from 0.22012
# Epoch 27/1000
# 118440/118440 [==============================] - 60s 508us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00027: loss improved from 0.22012 to 0.22012, saving model to lens-alnum.h5
# Epoch 28/1000
# 118440/118440 [==============================] - 55s 467us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00028: loss did not improve from 0.22012
# Epoch 29/1000
# 118440/118440 [==============================] - 54s 457us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00029: loss did not improve from 0.22012
# Epoch 30/1000
# 118440/118440 [==============================] - 63s 532us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00030: loss did not improve from 0.22012
# Epoch 31/1000
# 118440/118440 [==============================] - 56s 477us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00031: loss did not improve from 0.22012
# Epoch 32/1000
# 118440/118440 [==============================] - 56s 472us/step - loss: 0.2201 - accuracy: 0.9269 - val_loss: 0.4871 - val_accuracy: 0.8542
#
# Epoch 00032: loss did not improve from 0.22012
# Epoch 00032: early stopping

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 12))

fig.suptitle('Model Performance', fontsize=24) 

ax[0].plot(history.history['loss'], label='t-loss')
ax[0].plot(history.history['val_loss'], label='v-loss')
ax[0].set_title('Loss', fontsize=18)
ax[0].set_ylabel('Loss')

ax[1].plot(history.history['accuracy'], label='t-acc')
ax[1].plot(history.history['val_accuracy'], label='v-acc')
ax[1].set_title('Accuracy', fontsize=18)
ax[1].set_ylabel('Accuracy')


for i in range(2):
    ax[i].grid()
    ax[i].legend()
    ax[i].set_xlabel('Epochs')
    
plt.savefig('Training.png')
