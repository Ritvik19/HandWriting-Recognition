# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data

# %%
train = pd.read_csv('../Data/emnist/emnist-balanced-train.csv', header=None)
test = pd.read_csv('../Data/emnist/emnist-balanced-test.csv', header=None)

# %%
X_train = train.iloc[:, 1:].values
y_train = pd.get_dummies(train.iloc[:, 0]).values
X_test = test.iloc[:, 1:].values
y_test = pd.get_dummies(test.iloc[:, 0]).values

del train, test

# %%
print('Training Set')
print(len(X_train))
print(X_train.shape)
print(y_train.shape)
# Out:
# Training Set
# 112800
# (112800, 784)
# (112800, 47)

# %%
print('Testing Set')
print(len(X_test))
print(X_test.shape)
print(y_test.shape)
# Out:
# Testing Set
# 18800
# (18800, 784)
# (18800, 47)

# %%
X_all = np.concatenate((X_train, X_test))
y_all = np.concatenate((y_train,  y_test))

del X_train, y_train, X_test, y_test

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_all[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %%
def rotate(image):
    image = image.reshape([28, 28])
    image = np.fliplr(image)
    image = np.rot90(image)
    return image.reshape([28 * 28])
X_all = np.apply_along_axis(rotate, 1, X_all)

# %%
X_all = 255 - X_all
X_all = X_all.astype('float32')
X_all /= 255.0

# %%
fig, ax = plt.subplots(1, 10, figsize=(20, 6))
for i in range(10):
    ax[i].imshow(X_all[i].reshape([28, 28]),cmap=plt.get_cmap('gray'))

# %% [markdown]
# # Preprocessing

# %%
X_all = X_all.reshape(-1, 28, 28, 1)

X_all.shape
# Out:
# (131600, 28, 28, 1)

# %% [markdown]
# # Model Fitting

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Convolutional Neural Network

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
filepath = "lens-alnum.h5"
ckpt = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
rlp = ReduceLROnPlateau(patience=2)

def cnn(image_size):
    classifier = Sequential()
    classifier.add(Conv2D(128, (5, 5), input_shape = (*image_size, 1), activation = 'relu', padding='same'))
    classifier.add(Conv2D(128, (5, 5), activation = 'relu', padding='same'))
    classifier.add(MaxPooling2D(pool_size=(2, 2)))
    classifier.add(Dropout(0.25))
    classifier.add(Conv2D(256, (3, 3), activation = 'relu', padding='same'))
    classifier.add(Conv2D(256, (3, 3), activation = 'relu', padding='same'))
    classifier.add(MaxPooling2D(pool_size=(2, 2)))
    classifier.add(Dropout(0.25))
    classifier.add(Flatten())
    classifier.add(Dense(units = 47, activation = 'softmax'))
    classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
    classifier.summary()
    return classifier


model = cnn((28,28))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 128)       3328
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 128)       409728
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 256)       295168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 256)       590080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 47)                589615
# =================================================================
# Total params: 1,887,919
# Trainable params: 1,887,919
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
# Out:
# Using TensorFlow backend.

# %%
datagen = ImageDataGenerator(
    rotation_range=10, 
    zoom_range = 0.1,
    width_shift_range=0.1, 
    height_shift_range=0.1,
    validation_split=0.1
)  

datagen.fit(X_all)

training_set = datagen.flow(
    x=X_all, y=y_all,
    subset='training'
)

validation_set = datagen.flow(
    x=X_all, y=y_all,
    subset='validation'
)

# %%
history = model.fit_generator(training_set, validation_data=validation_set, epochs=1000, callbacks=[es, ckpt, rlp])
# Out:
# Epoch 1/1000
# 3700/3702 [============================>.] - ETA: 0s - loss: 0.7928 - accuracy: 0.7528
# Epoch 00001: loss improved from inf to 0.79248, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 55s 15ms/step - loss: 0.7925 - accuracy: 0.7529 - val_loss: 0.4696 - val_accuracy: 0.8467 - lr: 0.0010
# Epoch 2/1000
# 3699/3702 [============================>.] - ETA: 0s - loss: 0.4902 - accuracy: 0.8335
# Epoch 00002: loss improved from 0.79248 to 0.49032, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.4903 - accuracy: 0.8335 - val_loss: 0.4250 - val_accuracy: 0.8531 - lr: 0.0010
# Epoch 3/1000
# 3699/3702 [============================>.] - ETA: 0s - loss: 0.4466 - accuracy: 0.8461
# Epoch 00003: loss improved from 0.49032 to 0.44652, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.4465 - accuracy: 0.8461 - val_loss: 0.3951 - val_accuracy: 0.8619 - lr: 0.0010
# Epoch 4/1000
# 3700/3702 [============================>.] - ETA: 0s - loss: 0.4171 - accuracy: 0.8543
# Epoch 00004: loss improved from 0.44652 to 0.41697, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.4170 - accuracy: 0.8544 - val_loss: 0.3882 - val_accuracy: 0.8683 - lr: 0.0010
# Epoch 5/1000
# 3702/3702 [==============================] - ETA: 0s - loss: 0.4013 - accuracy: 0.8592
# Epoch 00005: loss improved from 0.41697 to 0.40132, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 53s 14ms/step - loss: 0.4013 - accuracy: 0.8592 - val_loss: 0.3667 - val_accuracy: 0.8743 - lr: 0.0010
# Epoch 6/1000
# 3700/3702 [============================>.] - ETA: 0s - loss: 0.3902 - accuracy: 0.8622
# Epoch 00006: loss improved from 0.40132 to 0.39029, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.3903 - accuracy: 0.8621 - val_loss: 0.3722 - val_accuracy: 0.8733 - lr: 0.0010
# Epoch 7/1000
# 3702/3702 [==============================] - ETA: 0s - loss: 0.3825 - accuracy: 0.8633
# Epoch 00007: loss improved from 0.39029 to 0.38251, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.3825 - accuracy: 0.8633 - val_loss: 0.3598 - val_accuracy: 0.8786 - lr: 0.0010
# Epoch 8/1000
# 3702/3702 [==============================] - ETA: 0s - loss: 0.3777 - accuracy: 0.8643
# Epoch 00008: loss improved from 0.38251 to 0.37771, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 55s 15ms/step - loss: 0.3777 - accuracy: 0.8643 - val_loss: 0.3622 - val_accuracy: 0.8777 - lr: 0.0010
# Epoch 9/1000
# 3699/3702 [============================>.] - ETA: 0s - loss: 0.3704 - accuracy: 0.8688
# Epoch 00009: loss improved from 0.37771 to 0.37037, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.3704 - accuracy: 0.8688 - val_loss: 0.3481 - val_accuracy: 0.8785 - lr: 0.0010
# Epoch 10/1000
# 3702/3702 [==============================] - ETA: 0s - loss: 0.3639 - accuracy: 0.8692
# Epoch 00010: loss improved from 0.37037 to 0.36391, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.3639 - accuracy: 0.8692 - val_loss: 0.3554 - val_accuracy: 0.8815 - lr: 0.0010
# Epoch 11/1000
# 3702/3702 [==============================] - ETA: 0s - loss: 0.3648 - accuracy: 0.8695
# Epoch 00011: loss did not improve from 0.36391
# 3702/3702 [==============================] - 54s 14ms/step - loss: 0.3648 - accuracy: 0.8695 - val_loss: 0.3504 - val_accuracy: 0.8768 - lr: 0.0010
# Epoch 12/1000
# 3700/3702 [============================>.] - ETA: 0s - loss: 0.3252 - accuracy: 0.8804
# Epoch 00012: loss improved from 0.36391 to 0.32520, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 53s 14ms/step - loss: 0.3252 - accuracy: 0.8804 - val_loss: 0.3268 - val_accuracy: 0.8851 - lr: 1.0000e-04
# Epoch 13/1000
# 3699/3702 [============================>.] - ETA: 0s - loss: 0.3133 - accuracy: 0.8854
# Epoch 00013: loss improved from 0.32520 to 0.31331, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.3133 - accuracy: 0.8854 - val_loss: 0.3226 - val_accuracy: 0.8890 - lr: 1.0000e-04
# Epoch 14/1000
# 3702/3702 [==============================] - ETA: 0s - loss: 0.3124 - accuracy: 0.8864
# Epoch 00014: loss improved from 0.31331 to 0.31242, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.3124 - accuracy: 0.8864 - val_loss: 0.3229 - val_accuracy: 0.8898 - lr: 1.0000e-04
# Epoch 15/1000
# 3699/3702 [============================>.] - ETA: 0s - loss: 0.3091 - accuracy: 0.8868
# Epoch 00015: loss improved from 0.31242 to 0.30908, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.3091 - accuracy: 0.8868 - val_loss: 0.3187 - val_accuracy: 0.8908 - lr: 1.0000e-04
# Epoch 16/1000
# 3700/3702 [============================>.] - ETA: 0s - loss: 0.3053 - accuracy: 0.8881
# Epoch 00016: loss improved from 0.30908 to 0.30519, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 14ms/step - loss: 0.3052 - accuracy: 0.8881 - val_loss: 0.3168 - val_accuracy: 0.8911 - lr: 1.0000e-04
# Epoch 17/1000
# 3701/3702 [============================>.] - ETA: 0s - loss: 0.3026 - accuracy: 0.8883
# Epoch 00017: loss improved from 0.30519 to 0.30266, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 14ms/step - loss: 0.3027 - accuracy: 0.8883 - val_loss: 0.3149 - val_accuracy: 0.8914 - lr: 1.0000e-04
# Epoch 18/1000
# 3698/3702 [============================>.] - ETA: 0s - loss: 0.3005 - accuracy: 0.8902
# Epoch 00018: loss improved from 0.30266 to 0.30047, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 55s 15ms/step - loss: 0.3005 - accuracy: 0.8902 - val_loss: 0.3134 - val_accuracy: 0.8921 - lr: 1.0000e-04
# Epoch 19/1000
# 3701/3702 [============================>.] - ETA: 0s - loss: 0.2962 - accuracy: 0.8905
# Epoch 00019: loss improved from 0.30047 to 0.29617, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 55s 15ms/step - loss: 0.2962 - accuracy: 0.8906 - val_loss: 0.3077 - val_accuracy: 0.8965 - lr: 1.0000e-04
# Epoch 20/1000
# 3701/3702 [============================>.] - ETA: 0s - loss: 0.2965 - accuracy: 0.8899
# Epoch 00020: loss did not improve from 0.29617
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.2965 - accuracy: 0.8899 - val_loss: 0.3115 - val_accuracy: 0.8940 - lr: 1.0000e-04
# Epoch 21/1000
# 3700/3702 [============================>.] - ETA: 0s - loss: 0.2945 - accuracy: 0.8907
# Epoch 00021: loss improved from 0.29617 to 0.29450, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.2945 - accuracy: 0.8907 - val_loss: 0.3137 - val_accuracy: 0.8909 - lr: 1.0000e-04
# Epoch 22/1000
# 3700/3702 [============================>.] - ETA: 0s - loss: 0.2910 - accuracy: 0.8917
# Epoch 00022: loss improved from 0.29450 to 0.29091, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.2909 - accuracy: 0.8917 - val_loss: 0.3020 - val_accuracy: 0.8963 - lr: 1.0000e-05
# Epoch 23/1000
# 3699/3702 [============================>.] - ETA: 0s - loss: 0.2897 - accuracy: 0.8934
# Epoch 00023: loss improved from 0.29091 to 0.28959, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.2896 - accuracy: 0.8934 - val_loss: 0.3084 - val_accuracy: 0.8949 - lr: 1.0000e-05
# Epoch 24/1000
# 3700/3702 [============================>.] - ETA: 0s - loss: 0.2911 - accuracy: 0.8926
# Epoch 00024: loss did not improve from 0.28959
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.2911 - accuracy: 0.8926 - val_loss: 0.3068 - val_accuracy: 0.8948 - lr: 1.0000e-05
# Epoch 25/1000
# 3701/3702 [============================>.] - ETA: 0s - loss: 0.2874 - accuracy: 0.8942
# Epoch 00025: loss improved from 0.28959 to 0.28737, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 55s 15ms/step - loss: 0.2874 - accuracy: 0.8942 - val_loss: 0.3124 - val_accuracy: 0.8919 - lr: 1.0000e-06
# Epoch 26/1000
# 3701/3702 [============================>.] - ETA: 0s - loss: 0.2895 - accuracy: 0.8928
# Epoch 00026: loss did not improve from 0.28737
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.2895 - accuracy: 0.8928 - val_loss: 0.3088 - val_accuracy: 0.8937 - lr: 1.0000e-06
# Epoch 27/1000
# 3700/3702 [============================>.] - ETA: 0s - loss: 0.2873 - accuracy: 0.8940
# Epoch 00027: loss improved from 0.28737 to 0.28730, saving model to lens-alnum.h5
# 3702/3702 [==============================] - 54s 15ms/step - loss: 0.2873 - accuracy: 0.8941 - val_loss: 0.3096 - val_accuracy: 0.8923 - lr: 1.0000e-07
# Epoch 00027: early stopping

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 12))

fig.suptitle('Model Performance', fontsize=24) 

ax[0].plot(history.history['loss'], label='t-loss')
ax[0].plot(history.history['val_loss'], label='v-loss')
ax[0].set_title('Loss', fontsize=18)
ax[0].set_ylabel('Loss')

ax[1].plot(history.history['accuracy'], label='t-acc')
ax[1].plot(history.history['val_accuracy'], label='v-acc')
ax[1].set_title('Accuracy', fontsize=18)
ax[1].set_ylabel('Accuracy')


for i in range(2):
    ax[i].grid()
    ax[i].legend()
    ax[i].set_xlabel('Epochs')
    
plt.savefig('history.png')
